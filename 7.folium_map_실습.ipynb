# %% [markdown]
# # 지도에 좌표 표시하기
# - 공식문서 : https://python-visualization.github.io/folium/latest/getting_started.html#Choropleth-maps

# %%
# uv add folium

# %%
import folium

# %%
# 디폴트 위경도 지정(포커싱), 지도사이트 Map 객체 생성
folium_map = folium.Map(location=[37.5662952, 126.9779451], zoom_start=16)

# %%
folium.Marker(location=[37.5662952, 126.9779451]).add_to(folium_map)

# %%
popup = folium.Popup('서울시청 위치', max_width=300)
folium.Marker(location=[37.5662952, 126.9779451], popup=popup).add_to(folium_map)

# %%
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b2884af822945cc83357b0c42bd8c4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b2884af822945cc83357b0c42bd8c4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b2884af822945cc83357b0c42bd8c4f = L.map(
#                 &quot;map_4b2884af822945cc83357b0c42bd8c4f&quot;,
#                 {
#                     center: [37.5662952, 126.9779451],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbdec668809723a070d03ad07456d569 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbdec668809723a070d03ad07456d569.addTo(map_4b2884af822945cc83357b0c42bd8c4f);
#
#
#             var marker_cf90bef88ee53d3bc4644b00fdd6bc94 = L.marker(
#                 [37.5662952, 126.9779451],
#                 {
# }
#             ).addTo(map_4b2884af822945cc83357b0c42bd8c4f);
#
#
#             var marker_87821a35a98564e9701f2ec0d62c33c3 = L.marker(
#                 [37.5662952, 126.9779451],
#                 {
# }
#             ).addTo(map_4b2884af822945cc83357b0c42bd8c4f);
#
#
#             var marker_c7c7a5ae5cf43059028ab00e80e0b18e = L.marker(
#                 [37.5662952, 126.9779451],
#                 {
# }
#             ).addTo(map_4b2884af822945cc83357b0c42bd8c4f);
#
#
#         var popup_52f2d483d99d654f9165d7c92c9e5453 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_6b7745e591900743a3c8fa7747eddd26 = $(`&lt;div id=&quot;html_6b7745e591900743a3c8fa7747eddd26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시청 위치&lt;/div&gt;`)[0];
#                 popup_52f2d483d99d654f9165d7c92c9e5453.setContent(html_6b7745e591900743a3c8fa7747eddd26);
#
#
#
#         marker_c7c7a5ae5cf43059028ab00e80e0b18e.bindPopup(popup_52f2d483d99d654f9165d7c92c9e5453)
#         ;
#
#
#
#
#             var marker_dea7aed00057d1c341f4250d0bc45d09 = L.marker(
#                 [37.5662952, 126.9779451],
#                 {
# }
#             ).addTo(map_4b2884af822945cc83357b0c42bd8c4f);
#
#
#         var popup_829f7895ad35b1260229479b638a2a11 = L.popup({
#   &quot;maxWidth&quot;: 10000,
# });
#
#
#
#                 var html_0c57636ebd0cc1cba1663506aaeafc68 = $(`&lt;div id=&quot;html_0c57636ebd0cc1cba1663506aaeafc68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시청 위치&lt;/div&gt;`)[0];
#                 popup_829f7895ad35b1260229479b638a2a11.setContent(html_0c57636ebd0cc1cba1663506aaeafc68);
#
#
#
#         marker_dea7aed00057d1c341f4250d0bc45d09.bindPopup(popup_829f7895ad35b1260229479b638a2a11)
#         ;
#
#
#
#
#             tile_layer_dbdec668809723a070d03ad07456d569.addTo(map_4b2884af822945cc83357b0c42bd8c4f);
#
#
#             var marker_8cd97fe714e43d2a87f4979118acd9d3 = L.marker(
#                 [37.5662952, 126.9779451],
#                 {
# }
#             ).addTo(map_4b2884af822945cc83357b0c42bd8c4f);
#
#
#         var popup_2dd2d077a5020ed75b75b83989f80b35 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_5a4b6bdd8e0edc846f83b7f40f9b1239 = $(`&lt;div id=&quot;html_5a4b6bdd8e0edc846f83b7f40f9b1239&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시청 위치&lt;/div&gt;`)[0];
#                 popup_2dd2d077a5020ed75b75b83989f80b35.setContent(html_5a4b6bdd8e0edc846f83b7f40f9b1239);
#
#
#
#         marker_8cd97fe714e43d2a87f4979118acd9d3.bindPopup(popup_2dd2d077a5020ed75b75b83989f80b35)
#         ;
#
#
#
#
#             var marker_e80e364687adda5b54b8899af06d4895 = L.marker(
#                 [37.5662952, 126.9779451],
#                 {
# }
#             ).addTo(map_4b2884af822945cc83357b0c42bd8c4f);
#
#
#         var popup_5b1e34b07aaefbe433cd00e5a8990ebe = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_2729e493c4c1e3e533cd86d2d6f34efe = $(`&lt;div id=&quot;html_2729e493c4c1e3e533cd86d2d6f34efe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시청 위치&lt;/div&gt;`)[0];
#                 popup_5b1e34b07aaefbe433cd00e5a8990ebe.setContent(html_2729e493c4c1e3e533cd86d2d6f34efe);
#
#
#
#         marker_e80e364687adda5b54b8899af06d4895.bindPopup(popup_5b1e34b07aaefbe433cd00e5a8990ebe)
#         ;
#
#
#
#
#             var marker_aaa28b476b33276c2b0baa44b8c4616b = L.marker(
#                 [37.5662952, 126.9779451],
#                 {
# }
#             ).addTo(map_4b2884af822945cc83357b0c42bd8c4f);
#
#
#         var popup_

# %%
import os

# 존재하지 않으면 폴더를 만듬
os.makedirs('map_data', exist_ok=True)

folium_map.save('map_data/folium_map.html')
